# %% [markdown]
# <a href="https://colab.research.google.com/github/SaifurShatil/Code-Comment-Generation-Using-ChatGPT/blob/main/Code-Comment-Generation-Using-ChatGPT%20/Code/Code_comment_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install sacrebleu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 2.7 MB/s eta 0:00:00
# ...

# %%
pip install sacremoses
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 7.8 MB/s eta 0:00:00
# ...

# %%
import sacrebleu
from sacremoses import MosesDetokenizer
md = MosesDetokenizer(lang='en')

# %%
refs = []

with open("/content/drive/MyDrive/Colab Notebooks/ref.txt") as test:
    for line in test:
        line = line.lower()
        line = line.strip().split()
        line = md.detokenize(line)
        refs.append(line)

# %%
print("Reference 1st sentence:", refs[0])
# Out:
# Reference 1st sentence: removes all parsers from this text area

# %%
refs = [refs]

# %%
preds = []

with open("/content/drive/MyDrive/Colab Notebooks/gen.txt") as pred:
    for line in pred:
        line = line.lower()
        line = line.strip().split()
        line = md.detokenize(line)
        preds.append(line)

print("MTed 1st sentence:", preds[0])
# Out:
# MTed 1st sentence: clears parsers if the parser manager is not null

# %%
refs
# Out:
# [['removes all parsers from this text area',
#   'assigns the specified id to the labelmap according to its label',
#   'loading bitmap with optimized loaded size less than specific pixels count',
#   'returns a hash code value for this object',
#   'saves the configuration file',
#   'greater than or equal comparison',
#   'builds a union coder with the given list of element coders. this list corresponds to a mapping of union tag to coder. union tags start at 0',
#   'evaluates if the dependency is targeted for a classpath type',
#   'initialize the activity data',
#   'checks if the given storage port is part of varray',
#   'start sendgroupfile activity',
#   'sets the list of excluded data centers',
#   'methods converts a decimal number into a binary number as a string',
#   'returns the length of the integer codon representation of this grammar',
#   'creates a new instance',
#   'creates an audio media that can be played in the background',
# ...

# %%
bleu = sacrebleu.corpus_bleu(preds, refs)
print(bleu.score)
# Out:
# 13.896237837298102

# %%
refs = []

with open("/content/drive/MyDrive/Colab Notebooks/ref.txt") as test:
    for line in test:
        line = line.lower()
        line = line.strip().split()
        line = md.detokenize(line)
        refs.append(line)

# %%
refs[0]
# Out:
# 'removes all parsers from this text area'

# %%
with open("/content/drive/MyDrive/Colab Notebooks/bleu.txt", "w+") as output:
    count = 0
    total_score = 0.0
    for line in zip(refs,preds):
        ref = line[0]
        pred = line[1]
        print(ref, "\t--->\t", pred)
        bleu = sacrebleu.sentence_bleu(pred, [ref], smooth_method='exp')
        print(bleu.score, "\n")
        total_score += bleu.score
        count += 1
        output.write(str(bleu.score) + "\n")
    avg_score = total_score / count
    output.write(str("average score") + "\n")
    output.write(str(avg_score) + "\n")
    print('avg_score: %.4f' % avg_score)
# Out:
# removes all parsers from this text area 	--->	 clears parsers if the parser manager is not null
# 4.767707020457095
#
# assigns the specified id to the labelmap according to its label 	--->	 assigns a database identifier (dbid) reference to a label in the label map
# 3.716499092256817
#
# loading bitmap with optimized loaded size less than specific pixels count 	--->	 loads a bitmap from the specified uri with optimization and size limit
# 4.456882760699063
#
# returns a hash code value for this object 	--->	 generates a hash code for the connectionrelativetime object
# 23.356898886410015
#
# saves the configuration file 	--->	 shuts down the system by saving the current state if an instance exists
# 3.0890553181566975
#
# greater than or equal comparison 	--->	 determines if this word is greater than or equal to another word
# 21.200626759025184
#
# ...

# %% [markdown]
# ***1 gram bleu avg score***

# %%
from nltk.translate.bleu_score import sentence_bleu

# %%
import nltk
from nltk.translate.bleu_score import SmoothingFunction

# %%
preds = []

with open("/content/drive/MyDrive/Colab Notebooks/gen.txt") as pred:
    for line in pred:
        line = line.lower()
        line = line.strip().split()
        preds.append(line)

print("MTed 1st sentence:", preds[0])
# Out:
# MTed 1st sentence: ['clears', 'parsers', 'if', 'the', 'parser', 'manager', 'is', 'not', 'null']

# %%
refs = []

with open("/content/drive/MyDrive/Colab Notebooks/ref.txt") as test:
    for line in test:
        line = line.lower()
        line = line.strip().split()
        refs.append(line)

# %%
refs[0]
# Out:
# ['Removes', 'all', 'parsers', 'from', 'this', 'text', 'area']

# %%
with open("/content/drive/MyDrive/Colab Notebooks/bleu1gram.txt", "w+") as output:
    count = 0
    total_score = 0.0
    cc = SmoothingFunction()
    for line in zip(refs,preds):
        ref = line[0]
        pred = line[1]
        print(ref, "\t--->\t", pred)
        bleu = sentence_bleu([ref], pred, weights=(1,0,0,0), smoothing_function=cc.method4)
        print(bleu, "\n")
        output.write(str(bleu) + "\n")
        total_score += bleu
        count += 1

    avg_score = total_score / count
    output.write(str("average score") + "\n")
    output.write(str(avg_score) + "\n")
    print('avg_score: %.4f' % avg_score)
# Out:
# ['removes', 'all', 'parsers', 'from', 'this', 'text', 'area'] 	--->	 ['clears', 'parsers', 'if', 'the', 'parser', 'manager', 'is', 'not', 'null']
# 0.11111111111111109
#
# ['assigns', 'the', 'specified', 'id', 'to', 'the', 'labelmap', 'according', 'to', 'its', 'label'] 	--->	 ['assigns', 'a', 'database', 'identifier', '(dbid)', 'reference', 'to', 'a', 'label', 'in', 'the', 'label', 'map']
# 0.30769230769230765
#
# ['loading', 'bitmap', 'with', 'optimized', 'loaded', 'size', 'less', 'than', 'specific', 'pixels', 'count'] 	--->	 ['loads', 'a', 'bitmap', 'from', 'the', 'specified', 'uri', 'with', 'optimization', 'and', 'size', 'limit']
# 0.25
#
# ['returns', 'a', 'hash', 'code', 'value', 'for', 'this', 'object'] 	--->	 ['generates', 'a', 'hash', 'code', 'for', 'the', 'connectionrelativetime', 'object']
# 0.625
#
# ['saves', 'the', 'configuration', 'file'] 	--->	 ['shuts', 'down', 'the', 'system', 'by', 'saving', 'the', 'current', 'state', 'if', 'an', 'instance', 'exists']
# ...

# %% [markdown]
# *2 gram score*

# %%
with open("/content/drive/MyDrive/Colab Notebooks/bleu2gram.txt", "w+") as output:
    count = 0
    total_score = 0.0
    cc = SmoothingFunction()
    for line in zip(refs,preds):
        ref = line[0]
        pred = line[1]
        print(ref, "\t--->\t", pred)
        bleu = sentence_bleu([ref], pred, weights=(0,1,0,0), smoothing_function=cc.method4)
        print(bleu, "\n")
        output.write(str(bleu) + "\n")
        total_score += bleu
        count += 1

    avg_score = total_score / count
    output.write(str("average score") + "\n")
    output.write(str(avg_score) + "\n")
    print('avg_score: %.4f' % avg_score)
# Out:
# ['removes', 'all', 'parsers', 'from', 'this', 'text', 'area'] 	--->	 ['clears', 'parsers', 'if', 'the', 'parser', 'manager', 'is', 'not', 'null']
# 0.02746530721670274
#
# ['assigns', 'the', 'specified', 'id', 'to', 'the', 'labelmap', 'according', 'to', 'its', 'label'] 	--->	 ['assigns', 'a', 'database', 'identifier', '(dbid)', 'reference', 'to', 'a', 'label', 'in', 'the', 'label', 'map']
# 0.021374577978846135
#
# ['loading', 'bitmap', 'with', 'optimized', 'loaded', 'size', 'less', 'than', 'specific', 'pixels', 'count'] 	--->	 ['loads', 'a', 'bitmap', 'from', 'the', 'specified', 'uri', 'with', 'optimization', 'and', 'size', 'limit']
# 0.022590060452618185
#
# ['returns', 'a', 'hash', 'code', 'value', 'for', 'this', 'object'] 	--->	 ['generates', 'a', 'hash', 'code', 'for', 'the', 'connectionrelativetime', 'object']
# 0.2857142857142857
#
# ...

# %% [markdown]
# ***3 gram***

# %%
with open("/content/drive/MyDrive/Colab Notebooks/bleu3gram.txt", "w+") as output:
    count = 0
    total_score = 0.0
    cc = SmoothingFunction()
    for line in zip(refs,preds):
        ref = line[0]
        pred = line[1]
        print(ref, "\t--->\t", pred)
        bleu = sentence_bleu([ref], pred, weights=(0,0,1,0), smoothing_function=cc.method4)
        print(bleu, "\n")
        output.write(str(bleu) + "\n")
        total_score += bleu
        count += 1

    avg_score = total_score / count
    output.write(str("average score") + "\n")
    output.write(str(avg_score) + "\n")
    print('avg_score: %.4f' % avg_score)
# Out:
# ['removes', 'all', 'parsers', 'from', 'this', 'text', 'area'] 	--->	 ['clears', 'parsers', 'if', 'the', 'parser', 'manager', 'is', 'not', 'null']
# 0.01569446126668728
#
# ['assigns', 'the', 'specified', 'id', 'to', 'the', 'labelmap', 'according', 'to', 'its', 'label'] 	--->	 ['assigns', 'a', 'database', 'identifier', '(dbid)', 'reference', 'to', 'a', 'label', 'in', 'the', 'label', 'map']
# 0.01165886071573426
#
# ['loading', 'bitmap', 'with', 'optimized', 'loaded', 'size', 'less', 'than', 'specific', 'pixels', 'count'] 	--->	 ['loads', 'a', 'bitmap', 'from', 'the', 'specified', 'uri', 'with', 'optimization', 'and', 'size', 'limit']
# 0.012424533248939999
#
# ['returns', 'a', 'hash', 'code', 'value', 'for', 'this', 'object'] 	--->	 ['generates', 'a', 'hash', 'code', 'for', 'the', 'connectionrelativetime', 'object']
# 0.16666666666666669
#
# ...

# %% [markdown]
# ***4 gram***

# %%
with open("/content/drive/MyDrive/Colab Notebooks/bleu4gram.txt", "w+") as output:
    count = 0
    total_score = 0.0
    cc = SmoothingFunction()
    for line in zip(refs,preds):
        ref = line[0]
        pred = line[1]
        print(ref, "\t--->\t", pred)
        bleu = sentence_bleu([ref], pred, weights=(0,0,0,1), smoothing_function=cc.method4)
        print(bleu, "\n")
        output.write(str(bleu) + "\n")
        total_score += bleu
        count += 1

    avg_score = total_score / count
    output.write(str("average score") + "\n")
    output.write(str(avg_score) + "\n")
    print('avg_score: %.4f' % avg_score)
# Out:
# ['removes', 'all', 'parsers', 'from', 'this', 'text', 'area'] 	--->	 ['clears', 'parsers', 'if', 'the', 'parser', 'manager', 'is', 'not', 'null']
# 0.009155102405567586
#
# ['assigns', 'the', 'specified', 'id', 'to', 'the', 'labelmap', 'according', 'to', 'its', 'label'] 	--->	 ['assigns', 'a', 'database', 'identifier', '(dbid)', 'reference', 'to', 'a', 'label', 'in', 'the', 'label', 'map']
# 0.006412373393653841
#
# ['loading', 'bitmap', 'with', 'optimized', 'loaded', 'size', 'less', 'than', 'specific', 'pixels', 'count'] 	--->	 ['loads', 'a', 'bitmap', 'from', 'the', 'specified', 'uri', 'with', 'optimization', 'and', 'size', 'limit']
# 0.0069025184716333355
#
# ['returns', 'a', 'hash', 'code', 'value', 'for', 'this', 'object'] 	--->	 ['generates', 'a', 'hash', 'code', 'for', 'the', 'connectionrelativetime', 'object']
# 0.04158883083359671
#
# ...

# %% [markdown]
# ***cumulative 4 gram bleu***

# %%
with open("/content/drive/MyDrive/Colab Notebooks/bleuc4gram.txt", "w+") as output:
    count = 0
    total_score = 0.0
    cc = SmoothingFunction()
    for line in zip(refs,preds):
        ref = line[0]
        pred = line[1]
        print(ref, "\t--->\t", pred)
        bleu = sentence_bleu([ref], pred, weights=(0.25,0.25,0.25,0.25), smoothing_function=cc.method4)
        print(bleu, "\n")
        output.write(str(bleu) + "\n")
        total_score += bleu
        count += 1

    avg_score = total_score / count
    output.write(str("average score") + "\n")
    output.write(str(avg_score) + "\n")
    print('avg_score: %.4f' % avg_score)
# Out:
# ['removes', 'all', 'parsers', 'from', 'this', 'text', 'area'] 	--->	 ['clears', 'parsers', 'if', 'the', 'parser', 'manager', 'is', 'not', 'null']
# 0.02573285025273419
#
# ['assigns', 'the', 'specified', 'id', 'to', 'the', 'labelmap', 'according', 'to', 'its', 'label'] 	--->	 ['assigns', 'a', 'database', 'identifier', '(dbid)', 'reference', 'to', 'a', 'label', 'in', 'the', 'label', 'map']
# 0.026480261910431388
#
# ['loading', 'bitmap', 'with', 'optimized', 'loaded', 'size', 'less', 'than', 'specific', 'pixels', 'count'] 	--->	 ['loads', 'a', 'bitmap', 'from', 'the', 'specified', 'uri', 'with', 'optimization', 'and', 'size', 'limit']
# 0.026380696981716002
#
# ['returns', 'a', 'hash', 'code', 'value', 'for', 'this', 'object'] 	--->	 ['generates', 'a', 'hash', 'code', 'for', 'the', 'connectionrelativetime', 'object']
# 0.18756826382863573
#
# ...

# %%
import nltk
from nltk.translate.bleu_score import SmoothingFunction

def nltk_sentence_bleu(hypotheses, references, order=4):
    refs = []
    count = 0
    total_score = 0.0
    cc = SmoothingFunction()
    for hyp, ref in zip(hypotheses, references):
        hyp = hyp.split()
        ref = ref.split()
        refs.append([ref])
        if len(hyp) < order:
            continue
        else:
            score = nltk.translate.bleu([ref], hyp, smoothing_function=cc.method4)
            total_score += score
            count += 1
    avg_score = total_score / count
    print('avg_score: %.4f' % avg_score)
    return avg_score

# %% [markdown]
# ***METEOR Score***
# Sentence METEOR
#
# METEOR mainly works on sentence evaluation rather than corpus evaluation

# %%
import sys
from nltk.translate.meteor_score import meteor_score

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
with open("/content/drive/MyDrive/Colab Notebooks/meteor.txt", "w+") as output:
    count = 0
    total_score = 0.0
    for line in zip(refs, preds):
        test = line[0]
        pred = line[1]
        print(test, pred)

        meteor = round(meteor_score([test], pred), 2) # list of references
        print(meteor, "\n")
        output.write(str(meteor) + "\n")
        total_score += meteor
        count += 1

    avg_score = total_score / count
    output.write(str("average score") + "\n")
    output.write(str(avg_score) + "\n")
    print('avg_score: %.4f' % avg_score)
# Out:
# ['removes', 'all', 'parsers', 'from', 'this', 'text', 'area'] ['clears', 'parsers', 'if', 'the', 'parser', 'manager', 'is', 'not', 'null']
# 0.07
#
# ['assigns', 'the', 'specified', 'id', 'to', 'the', 'labelmap', 'according', 'to', 'its', 'label'] ['assigns', 'a', 'database', 'identifier', '(dbid)', 'reference', 'to', 'a', 'label', 'in', 'the', 'label', 'map']
# 0.18
#
# ['loading', 'bitmap', 'with', 'optimized', 'loaded', 'size', 'less', 'than', 'specific', 'pixels', 'count'] ['loads', 'a', 'bitmap', 'from', 'the', 'specified', 'uri', 'with', 'optimization', 'and', 'size', 'limit']
# 0.34
#
# ['returns', 'a', 'hash', 'code', 'value', 'for', 'this', 'object'] ['generates', 'a', 'hash', 'code', 'for', 'the', 'connectionrelativetime', 'object']
# 0.56
#
# ['saves', 'the', 'configuration', 'file'] ['shuts', 'down', 'the', 'system', 'by', 'saving', 'the', 'current', 'state', 'if', 'an', 'instance', 'exists']
# 0.38
#
# ...
